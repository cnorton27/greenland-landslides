# %%
# Ataa

from osgeo import gdal
import geopandas as gpd
import pandas as pn
import numpy as np
import rasterio as rio
import matplotlib.pyplot as plt
import os

from raster_utils import differencing, calculate_vol_loss

output_dir = r"C:\Users\hanna\Documents\Ataa"
raster_1 = r"C:\Users\hanna\Downloads\Arctic DTU gæsteforelæsning 2026\Data for exercises\DEM's and Hillshade\Aataa_Paatuut_newDEMdrone25_msl_utm22n_2m.tif"
raster_2 = r"C:\Users\hanna\Downloads\Arctic DTU gæsteforelæsning 2026\Data for exercises\DEM's and Hillshade\Paatuut_Aataa_oldDEM_SDFE_2m_msl_utm22n.tif"
cutline = r"C:\Users\hanna\Documents\greenland-landslides\data-hanna\Ataa_cropped.shp"
res = 2

diff1 = differencing(raster_1, raster_2, cutline, res, res, "Ataa_cropped", output_dir) 
calculate_vol_loss(diff1, 0)

# Result:
# Total volume change: -671538085888.00 Total volume lost: 671633833984.00 Total vol deposited: 95713016.00
# Out:
# Calculating DOD for Ataa_cropped
# 2.0 2.0
# Total volume change: -671538085888.00 Total volume lost: 671633833984.00 Total vol deposited: 95713016.00

# %%
# Ataa

from osgeo import gdal
import geopandas as gpd
import pandas as pn
import numpy as np
import rasterio as rio
import matplotlib.pyplot as plt
import os

from raster_utils import differencing, calculate_vol_loss

output_dir = r"C:\Users\hanna\Documents\Ataa"
raster_1 = r"C:\Users\hanna\Downloads\Arctic DTU gæsteforelæsning 2026\Data for exercises\DEM's and Hillshade\Aataa_Paatuut_newDEMdrone25_msl_utm22n_2m.tif"
raster_2 = r"C:\Users\hanna\Downloads\Arctic DTU gæsteforelæsning 2026\Data for exercises\DEM's and Hillshade\Paatuut_Aataa_oldDEM_SDFE_2m_msl_utm22n.tif"
cutline = r"C:\Users\hanna\Documents\greenland-landslides\data-hanna\Ataa_cropped.shp"
res = 2

diff1 = differencing(raster_1, raster_2, cutline, res, res, "Ataa_cropped", output_dir) 
calculate_vol_loss(diff1) 

# Result:
# Total volume change: -40169500.00 Total volume lost: 135882528.00 Total vol deposited: 95713016.00
# Out:
# Calculating DOD for Ataa_cropped
# C:\Users\hanna\miniconda3\envs\greenland\Lib\site-packages\osgeo\gdal.py:606: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# 2.0 2.0
# Total volume change: -40169500.00 Total volume lost: 135882528.00 Total vol deposited: 95713016.00
